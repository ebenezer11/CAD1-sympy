# %%
from sympy import*
x,y = symbols('x,y')
f = Function('f')(x**3+2*x-1)
f.diff()
# Out:
# (3*x**2 + 2)*Subs(Derivative(f(_xi_1), _xi_1), (_xi_1,), (x**3 + 2*x - 1,))

# %%
diff(f.diff())
# Out:
# 6*x*Subs(Derivative(f(_xi_1), _xi_1), (_xi_1,), (x**3 + 2*x - 1,)) + (3*x**2 + 2)**2*Subs(Derivative(f(_xi_1), _xi_1, _xi_1), (_xi_1,), (x**3 + 2*x - 1,))

# %%
f =x**3+2*x-1
diff(f,x)
# Out:
# 3*x**2 + 2

# %%
diff(diff(f,x))
# Out:
# 6*x

# %%
def f(x):
    return x**3+2*x-1
f(x)
print(diff(f(x),x))
# Out:
# 3*x**2 + 2

# %%
f=atan(x)

# %%
diff(f,x)
# Out:
# 1/(x**2 + 1)

# %%
integrate(diff(f,x))
# Out:
# atan(x)

# %%
f = cos(x)+ sin(x)
diff(f,x)
# Out:
# -sin(x) + cos(x)

# %%
integrate(diff(f,x))
# Out:
# sin(x) + cos(x)

# %%
f = (x/(x**3+1))

# %%
diff(f,x)
# Out:
# -3*x**3/(x**3 + 1)**2 + 1/(x**3 + 1)

# %%
integrate(diff(f,x))
# Out:
# x/(x**3 + 1)

# %%
f = exp(2*x)
d = integrate(f,x)
g = diff(d, x)
g
# Out:
# exp(2*x)

# %%
w, a = symbols('w, a')
integrate(x*exp(-a*x)*cos(w*x),(x, 0, oo)).simplify()
# Out:
# Piecewise(((a**2 - w**2)/(a**2 + w**2)**2, Eq(Abs(periodic_argument(polar_lift(w)**2, oo)), 0) & (Abs(periodic_argument(polar_lift(a)**2, oo)) < pi)), (Integral(x*exp(-a*x)*cos(w*x), (x, 0, oo)), True))

# %%
u = symbols ('u')
plot(sin(u), (u, 0, pi/2))

# %%
plot(cos(u),(u, 0, pi/2))

# %%
plot((2*cos(x)-2+3*sin(2*x)), (x, -pi, pi))

# %%
plot(x**2, x**3, x**4-x+1,(x,-10,10))

# %%
p1 = plot(x**2,(x,-10,10))
p2 = plot(x**3,(x,-10,10))

# %%
print(p1)
# Out:
# Plot object containing:
# [0]: cartesian line: x**2 for x over (-10.0, 10.0)

# %%
p1.extend(p2)

# %%
p1.show()

# %%
plot(x**2,(x,-5,5),line_color = 'green')

# %%
c1 = 2*cos(x)-2+3*sin(2*x)
p1 = plot(cos(x),c1,(x,-pi,pi),legend = True, show = False)
p1[0].line_color ='b'
p1[1].line_color = 'r'
p1.show()

# %%
l = [cos(n*x) for n in range(1,4)]
p3 =plot(*l, (x,0,2*pi), show=False, title ='nana')
p3[0].line_color ='r'
p3[1].line_color ='b'
p3[2].line_color ='k'
p3.show()

# %%
plotting.plot_parametric((cos(u),sin(u),(u, -pi, pi)))

# %%
plotting.plot_parametric(cos(u),sin(u),(u, -pi, pi), xlim=(-3, 3), ylim=(-3,3))

# %%
x, y = symbols('x y')
plotting.plot3d((x*y)**2, (x, -5, 5), (y, -5, 5))

# %%
plotting.plot3d_parametric_line(cos(u), sin(u), u, (u, -5, 5))

# %%
plotting.plot_parametric((cos(u),sin(u),(u, -pi,pi)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-45e53bf7adc9> in <module>()
# ----> 1 plotting.plot3d_parametric_surface(cos(u+t), sin(u-t), u-t, (u, 0, 5), (t, 0, 5))
#
# NameError: name 't' is not defined
